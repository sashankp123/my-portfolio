# %%
from googleapiclient.discovery import build

# Your API key goes here
api_key = 'AIzaSyBNzopQAApuOsAqEJfgpXVfqyILRCFrMqA'

# Building the service object
youtube = build('youtube', 'v3', developerKey=api_key)

# Step 2: Print out the name of the city you have been assigned to
assigned_city = "Elk Grove"
print(assigned_city)

# Step 3: Use the Youtube API to search for the videos related to your assigned city
search_response = youtube.search().list(
    q=assigned_city,
    part='id,snippet',
    maxResults=100,
    type='video'
).execute()

# Step 4: Get the video details
video_ids = []
for item in search_response.get('items', []):
    if item['id']['kind'] == 'youtube#video':
        video_ids.append(item['id']['videoId'])

# Get video details
videos_response = youtube.videos().list(
    id=','.join(video_ids),
    part='id,snippet,statistics'
).execute()

# Step 5: Print out the details for each video
# Step 5: Print out the details for each video, with error handling for missing 'likeCount'
for video in videos_response.get('items', []):
    title = video['snippet']['title']
    video_id = video['id']
    view_count = video['statistics'].get('viewCount', 'Not available')

    # Some videos may not have a 'likeCount' if likes are disabled
    like_count = video['statistics'].get('likeCount', 'Not available')

    # Print formatted results
    print(f"Title: {title}\nVideo Id: {video_id}\nNumber of Views: {view_count}\nNumber of Likes: {like_count}")
    print("★" * 30)
# Out:
# Elk Grove
# Title: David Kushner - Elk Grove (Lyric Video)
# Video Id: 5if5s7dlMOM
# Number of Views: 206268
# Number of Likes: 4896
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: David Kushner - Elk Grove (Official Video)
# Video Id: pjyN3rOhJl4
# Number of Views: 2689594
# Number of Likes: 64833
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: The Top 7 Reasons You Shouldn't Move To Elk Grove California
# Video Id: CFsIrB_x3Og
# Number of Views: 4697
# Number of Likes: 49
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: What’s it like living in Elk Grove CA?
# Video Id: 12PW4TgvqaA
# Number of Views: 3136
# Number of Likes: 68
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Living in Elk Grove California | Pros and Cons of Elk Grove
# Video Id: vd79Bu8ouLM
# Number of Views: 4382
# Number of Likes: 92
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Top Things To Do in Elk Grove California | Moving to Elk Grove CA
# Video Id: xi-M0zOvROQ
# Number of Views: 4427
# Number of Likes: 50
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Asking $3.2 Million, One of a kind home in Elk Grove CA where old world craftsmanship meets luxury
# Video Id: Ynep6kbxkUY
# Number of Views: 46317
# Number of Likes: 959
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Driving Tour Of Elk Grove, California
# Video Id: kNrN_ozrPew
# Number of Views: 4121
# Number of Likes: 39
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Sprawling Elk Grove Estate on 20 Acres of Serene Landscape asking for $6,700,000
# Video Id: a_r-sqqaSMk
# Number of Views: 12822
# Number of Likes: 405
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Elk Grove Vs Roseville | Which City Is BETTER?
# Video Id: swPCYMW5_Io
# Number of Views: 2580
# Number of Likes: 47
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Pros and Cons of Living in Elk Grove | Moving to Elk Grove, Ca
# Video Id: b_KRhRBtA5Y
# Number of Views: 5943
# Number of Likes: 78
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Elk Grove California | Dash Cam | USA |Driving Tour Video
# Video Id: ypRTorxzcY4
# Number of Views: 10831
# Number of Likes: 115
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Living in ELK GROVE California | Everything You Need To Know About Elk Grove CA
# Video Id: 63j_1FM7ReU
# Number of Views: 932
# Number of Likes: 11
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Elk Grove on their toes not knowing when the next explosion will go off
# Video Id: rxOTLOsEOSQ
# Number of Views: 17656
# Number of Likes: 226
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Elk Grove man uses TikTok to document his father's onset dementia
# Video Id: jD4pY4jyNxA
# Number of Views: 81846
# Number of Likes: 2001
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: 5 Things You Need to Know Before Moving to Elk Grove
# Video Id: nZBGqG00vF0
# Number of Views: 1340
# Number of Likes: 31
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Laguna West // Elk Grove - Sacramento California
# Video Id: XrWjx79s2x4
# Number of Views: 8927
# Number of Likes: 135
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Elk Grove Bike Park Rebuild
# Video Id: z5fkAWhbTaE
# Number of Views: 1047
# Number of Likes: 20
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Elk Grove Unified School District v. Newdow Case Brief Summary | Law Case Explained
# Video Id: 5kxMgG7fnuI
# Number of Views: 2459
# Number of Likes: 21
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Moving To Elk Grove California Neighborhood Tour | Laguna West
# Video Id: kbeqovuAXMY
# Number of Views: 1072
# Number of Likes: 17
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Sport Lab CA - Elk Grove
# Video Id: e4lTPyTWMIg
# Number of Views: 474
# Number of Likes: 5
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Family of Elk Grove Village man shot dead by police announces civil investigation
# Video Id: vplmQ81vAio
# Number of Views: 2476
# Number of Likes: 23
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Elk Grove hosts third annual Lunar New Year celebration
# Video Id: 1QXvaUnJRm8
# Number of Views: 857
# Number of Likes: 9
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Game of the Week - Elk Grove at Franklin, Boys Basketball 1-11-19
# Video Id: HtnU-f6TnQY
# Number of Views: 4465
# Number of Likes: 34
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Title: Elk Grove father, son duo go viral on TikTok for raising dementia awareness
# Video Id: UUK3w4Lftf0
# Number of Views: 246326
# Number of Likes: 7704
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★

# %%
import matplotlib.pyplot as plt

# Lists to store video titles, view counts, and like counts
titles = []
view_counts = []
like_counts = []

# Extract data from the API response
for video in videos_response.get('items', []):
    title = video['snippet']['title']
    view_count = int(video['statistics'].get('viewCount', 0))  # Convert to int, default to 0 if viewCount is missing
    like_count = int(video['statistics'].get('likeCount', 0))  # Convert to int, default to 0 if likeCount is missing

    # Append data to lists
    titles.append(title)
    view_counts.append(view_count)
    like_counts.append(like_count)

# Plotting the data
plt.figure(figsize=(10, 6))
plt.bar(range(len(titles)), view_counts, color='blue', label='Views')
plt.bar(range(len(titles)), like_counts, color='green', label='Likes')
plt.xlabel('Videos')
plt.ylabel('Count')
plt.title('Number of Views and Likes for Videos Related to ' + assigned_city)
plt.xticks(range(len(titles)), titles, rotation=90)  # Rotate x-axis labels for better readability
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
# Out:
# <ipython-input-23-84bc2cf2eb96>:28: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()  # Adjust layout to prevent clipping of labels

# %%
import matplotlib.pyplot as plt

# Collect views and likes, excluding videos with missing 'likeCount'
views = []
likes = []
for video in videos_response.get('items', []):
    if 'likeCount' in video['statistics']:
        views.append(int(video['statistics']['viewCount']))
        likes.append(int(video['statistics']['likeCount']))

# Now you have lists of views and likes with corresponding indices
plt.figure(figsize=(10, 5))
plt.scatter(views, likes)
plt.title('Relationship between Views and Likes')
plt.xlabel('Number of Views')
plt.ylabel('Number of Likes')
plt.grid(True)
plt.show()

# %%
print("I chose a bar graph to visualize the number of views and likes for each video related to the assigned city because it offers a clear and compact comparison between the two metrics. With each video represented by a pair of bars—one for views and one for likes—the graph allows for straightforward comparison across multiple videos. The use of different colors for views and likes enhances visual distinction, while displaying video titles on the x-axis ensures easy identification of each data point. By presenting the data in this format, viewers can quickly grasp the relative popularity of videos in terms of both views and likes, aiding in the understanding of viewer engagement with content related to the assigned city.")
# Out:
# I chose a bar graph to visualize the number of views and likes for each video related to the assigned city because it offers a clear and compact comparison between the two metrics. With each video represented by a pair of bars—one for views and one for likes—the graph allows for straightforward comparison across multiple videos. The use of different colors for views and likes enhances visual distinction, while displaying video titles on the x-axis ensures easy identification of each data point. By presenting the data in this format, viewers can quickly grasp the relative popularity of videos in terms of both views and likes, aiding in the understanding of viewer engagement with content related to the assigned city.
